# %% [markdown]
# En este ejercicio pondremos en práctica los conceptos básicos para juntar varios csv que compartan información.
# Trabajaremos con tres ficheros diferentes:
# * El csv que creamos en el ejercicio de pair programming Pandas IV, dónde recordamos eliminamos ciertas columnas que no eran necesarias, y habíamos creado nuevas.
# * El csv llamado attacks_historico donde tenemos información sobre los ataques de tiburón previos al año 1800.
#
# * El csv llamado attacks_adicional donde tenemos información sobre los ataques de tiburón.
#
# El principal objetivo de este ejercicio de pair programming es acabar teniendo un único DataFrame con toda la información contenida en los tres csv anteriores.
#
# Para llevar a cabo nuestro objetivo tendréis que seguir los siguientes pasos:
#
# 1. Cargad los tres ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos y saber que información tienen en común y debatir con tu compañera como podríamos juntar toda la información.
#
# 2. Chequead que los nombres de las columnas que sean iguales entre dataframes son iguales. ¿Están todas en minúsculas? ¿Tienen espacios? En caso de que no sean todas iguales unificad el nombre de las columnas.
#
# 3. En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV es similar al DataFrame de los datos historicos. Si recordamos, eliminamos algunas columnas en la sesión III que no eran útiles, pero esas columnas están todavía en el histórico. Si no fuera por eso podríamos unir esos dataframes. Realizad los cambios que creais necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.
#
# 4. Es el momento de unir la información de todos los ataques de tiburón que acabamos de crear con el DataFrame de información adicional. Debatid que método es el más correcto para unir toda esta información y ejecutadlo.
# 📌 NOTA Cuando hagáis la unión considerad que la información que más nos interesa es la del DataFrame que creamos en el apartado anterior, lo cual determinará el tipo de unión.
#
# 5. Guardad el dataframe nuevo en un csv que usaremos mañana en la clase de pair programming

# %%
import pandas as pd
import numpy as np

# %%
# ejercicio 1
df = pd.read_csv('attacks_modificado_2.csv')
df.head(2)
# Out:
#    Unnamed: 0   case_number  unnamed:_0    year        type country  \
# 0           0    2018.06.25           0  2018.0     Boating     USA
# 1           6  2018.06.03.a           6  2018.0  Unprovoked  BRAZIL
#
#          area                     location  activity                    name  \
# 0  California  Oceanside, San Diego County  Paddling             Julie Wolfe
# 1  Pernambuco        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva
#
#   sex_ age            time     species_  \
# 0    F  57           18h00  White shark
# 1    M  18  Late afternoon  Tiger shark
#
#                                                 href      siglo
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI

# %%
# No sabemos por qué se nos ha creado una columna llamada Unnamed: 0. La eliminamos

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace= True)

# %%
df.shape
# Out:
# (1502, 15)

# %%
df.isnull().sum()
# Out:
# case_number    0
# unnamed:_0     0
# year           0
# type           0
# country        0
# area           0
# location       0
# activity       0
# name           0
# sex_           0
# age            0
# time           0
# species_       0
# href           0
# siglo          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href', 'siglo'],
#       dtype='object')

# %%
# Cargamos el df historico y lo exploramos

# %%
df_hi = pd.read_csv('attacks_historico.csv')
df_hi.head(2)
# Out:
#    Unnamed: 0   Case Number    Year        Type     Country      Area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   Location                         Activity   Name Sex   ... Species   \
# 0      NaN  a corsair's boat was overturned    NaN    F  ...      NaN
# 1      NaN                Dropped overboard  child  NaN  ...      NaN
#
#    Investigator or Source                          pdf  \
# 0      V. C. Harvey-Brain  1800.00.00-Corsair-boat.pdf
# 1  The Observer 5/28/1797  1797.05.28.R-Cloverdale.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
#
#   Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    1800.00.00          171.0         NaN          NaN
# 1  1797.05.28.R          170.0         NaN          NaN
#
# [2 rows x 22 columns]

# %%
df_hi.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df_hi.shape
# Out:
# (170, 22)

# %%
df_hi.isnull().sum()
# Out:
# Unnamed: 0                  0
# Case Number                 0
# Year                        0
# Type                        0
# Country                    10
# Area                       46
# Location                   51
# Activity                   31
# Name                        9
# Sex                        14
# Age                       154
# Time                      160
# Species                   126
# Investigator or Source      1
# pdf                         0
# href formula                0
# href                        0
# Case Number.1               0
# Case Number.2               0
# original order              0
# Unnamed: 22               170
# Unnamed: 23               170
# dtype: int64

# %%
# Cargamos el df adicional y lo exploramos

df_adi = pd.read_csv('attacks_adicional.csv', index_col = 0)
df_adi.head(2)
# Out:
#   Case Number Fatal (Y/N)                                             Injury  \
# 0  2018.06.25           N  No injury to occupant, outrigger canoe and pad...
# 1  2018.06.18           N                         Minor injury to left thigh
#
#           Date
# 0  25-Jun-2018
# 1  18-Jun-2018

# %%
# ejercicio 2
# Vamos a hacer la modificaciones necesarias al df histórico

# %%
# Renombramos las columnas

# %%
columnas_nuevas = {col :  col.lower().replace(' ', '_') for col in df_hi.columns}

# %%
df_hi.rename(columns = columnas_nuevas, inplace = True)
df_hi.head(2)
# Out:
#    unnamed:_0   case_number    year        type     country      area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   location                         activity   name sex_  ... species_  \
# 0      NaN  a corsair's boat was overturned    NaN    F  ...      NaN
# 1      NaN                Dropped overboard  child  NaN  ...      NaN
#
#    investigator_or_source                          pdf  \
# 0      V. C. Harvey-Brain  1800.00.00-Corsair-boat.pdf
# 1  The Observer 5/28/1797  1797.05.28.R-Cloverdale.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case_number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
#
#   case_number.2 original_order unnamed:_22  unnamed:_23
# 0    1800.00.00          171.0         NaN          NaN
# 1  1797.05.28.R          170.0         NaN          NaN
#
# [2 rows x 22 columns]

# %%
#renombramos las columnas del df_adi(miinusculas)
columnas_nuevas_adi = {col :  col.lower().replace(' ', '_') for col in df_adi.columns}

# %%
df_adi.rename(columns = columnas_nuevas_adi, inplace = True)
df_adi.head(2)
# Out:
#   case_number fatal_(y/n)                                             injury  \
# 0  2018.06.25           N  No injury to occupant, outrigger canoe and pad...
# 1  2018.06.18           N                         Minor injury to left thigh
#
#           date
# 0  25-Jun-2018
# 1  18-Jun-2018

# %%
# Eliminamos las mismas columnas que eliminamos en el df que modificamos primero

# %%
df_hi.drop(["unnamed:_23", "case_number.1", "unnamed:_22", "case_number.2", "original_order", "investigator_or_source", "pdf", "href_formula"], axis = 1, inplace = True)
df_hi.shape
# Out:
# (170, 14)

# %%
df_hi
# Out:
#      unnamed:_0   case_number    year        type             country  \
# 0          6132    1800.00.00  1800.0  Unprovoked          SEYCHELLES
# 1          6133  1797.05.28.R  1797.0  Unprovoked                 NaN
# 2          6134    1792.09.12  1792.0    Provoked             ENGLAND
# 3          6135    1791.00.00  1791.0  Unprovoked           AUSTRALIA
# 4          6136    1788.05.10  1788.0        Boat           AUSTRALIA
# ..          ...           ...     ...         ...                 ...
# 165        6297       ND.0005     0.0  Unprovoked           AUSTRALIA
# 166        6298       ND.0004     0.0  Unprovoked           AUSTRALIA
# 167        6299       ND.0003     0.0  Unprovoked                 USA
# 168        6300       ND.0002     0.0  Unprovoked              PANAMA
# 169        6301       ND.0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   area                             location  \
# 0             St. Anne                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                  On the Thames River
# 3      New South Wales                         Port Jackson
# 4      New South Wales                        Sydney Harbor
# ..                 ...                                  ...
# 165  Western Australia                          Roebuck Bay
# 166  Western Australia                                  NaN
# 167     North Carolina                       Ocracoke Inlet
# 168                NaN                 Panama Bay 8ºN, 79ºW
# 169   Eastern Province  Below the English fort, Trincomalee
#
#                             activity                              name sex_  \
# 0    a corsair's boat was overturned                               NaN    F
# 1                  Dropped overboard                             child  NaN
# 2                            Fishing                              male    M
# 3                                NaN  female, an Australian aboriginal    F
# 4                            Fishing                              boat  NaN
# ..                               ...                               ...  ...
# 165                           Diving                              male    M
# 166                     Pearl diving                             Ahmun    M
# 167                         Swimming             Coast Guard personnel    M
# 168                              NaN                   Jules Patterson    M
# 169                         Swimming                              male    M
#
#      age time species_                                               href
# 0    NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1    NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2    NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3    NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4    NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# ..   ...  ...      ...                                                ...
# 165  NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 166  NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 167  NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 168  NaN  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 169   15  NaN      NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [170 rows x 14 columns]

# %%
# Chequeamos los nulos
df_hi.isnull().sum()
# Out:
# unnamed:_0       0
# case_number      0
# year             0
# type             0
# country         10
# area            46
# location        51
# activity        31
# name             9
# sex_            14
# age            154
# time           160
# species_       126
# href             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href', 'siglo'],
#       dtype='object')

# %%
df_hi.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
# ejercicio 3

# %%
#ordenamos las columnas del df para que el orden sea igual que df_hi
df = df[['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
       'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
       'href']]

# %%
#añadimos la columna "siglo" al df_hi
df_hi['siglo'] = np.where((df_hi['year']<2000), 'siglo-XX', 'siglo-XXI')

# %%
# ejercicio 4
#juntamos los df + df_hi

# %%
df_all = pd.concat([df, df_hi], axis = 0)
df_all
# Out:
#      unnamed:_0   case_number    year        type             country  \
# 0             0    2018.06.25  2018.0     Boating                 USA
# 1             6  2018.06.03.a  2018.0  Unprovoked              BRAZIL
# 2             8  2018.05.26.b  2018.0  Unprovoked                 USA
# 3            10    2018.05.24  2018.0    Provoked           AUSTRALIA
# 4            13  2018.05.13.a  2018.0     Invalid             ENGLAND
# ..          ...           ...     ...         ...                 ...
# 165        6297       ND.0005     0.0  Unprovoked           AUSTRALIA
# 166        6298       ND.0004     0.0  Unprovoked           AUSTRALIA
# 167        6299       ND.0003     0.0  Unprovoked                 USA
# 168        6300       ND.0002     0.0  Unprovoked              PANAMA
# 169        6301       ND.0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   area                             location        activity  \
# 0           California          Oceanside, San Diego County        Paddling
# 1           Pernambuco                Piedade Beach, Recife        Swimming
# 2              Florida         Cocoa Beach, Brevard  County         Walking
# 3           Queensland                      Cairns Aquarium  Feeding sharks
# 4             Cornwall                       Off Land's End         Fishing
# ..                 ...                                  ...             ...
# 165  Western Australia                          Roebuck Bay          Diving
# 166  Western Australia                                  NaN    Pearl diving
# 167     North Carolina                       Ocracoke Inlet        Swimming
# 168                NaN                 Panama Bay 8ºN, 79ºW             NaN
# 169   Eastern Province  Below the English fort, Trincomalee        Swimming
#
#                        name sex_  age            time          species_  \
# 0               Julie Wolfe    F   57           18h00       White shark
# 1    Jose Ernesto da Silva     M   18  Late afternoon       Tiger shark
# 2                 Cody High    M   15           17h00    Bull shark, 6'
# 3                      male    M   32         Morning   Grey reef shark
# 4              Max Berryman    M   21           08h15  Invalid incident
# ..                      ...  ...  ...             ...               ...
# 165                    male    M  NaN             NaN               NaN
# 166                   Ahmun    M  NaN             NaN               NaN
# 167   Coast Guard personnel    M  NaN             NaN               NaN
# 168         Jules Patterson    M  NaN             NaN               NaN
# 169                    male    M   15             NaN               NaN
#
#                                                   href     siglo
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...       NaN
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...       NaN
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...       NaN
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...       NaN
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...       NaN
# ..                                                 ...       ...
# 165  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 166  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 167  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 168  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 169  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
#
# [1672 rows x 15 columns]

# %%
# juntamos df_all + df.adi
df_all_all = df_all.merge(df_adi, how = "left", on= "case_number")
df_all_all.head(2)
# Out:
#    unnamed:_0   case_number    year        type country        area  \
# 0           0    2018.06.25  2018.0     Boating     USA  California
# 1           6  2018.06.03.a  2018.0  Unprovoked  BRAZIL  Pernambuco
#
#                       location  activity                    name sex_ age  \
# 0  Oceanside, San Diego County  Paddling             Julie Wolfe    F  57
# 1        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
#
#              time     species_  \
# 0           18h00  White shark
# 1  Late afternoon  Tiger shark
#
#                                                 href siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   NaN           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   NaN           Y
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                                              FATAL  03-Jun-2018

# %%
df_all_all.shape
# Out:
# (1672, 18)

# %%
# ejercicio 5
#guardamos el nuevo df_all_all
df_all_all.to_csv("attacks_modificado_3.csv")
