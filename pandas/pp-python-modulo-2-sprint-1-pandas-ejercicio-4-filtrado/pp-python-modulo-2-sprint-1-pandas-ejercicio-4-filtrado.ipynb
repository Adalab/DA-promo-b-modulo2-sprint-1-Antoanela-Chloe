# %% [markdown]
# 1. Cargad el csv que guardasteis ayer.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('attacks_modificado.csv')
df.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
df.shape
# Out:
# (6114, 14)

# %% [markdown]
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.

# %%
# Preferimos ejecutarlo y guardarlo en una variable nueva, para poder comparar luego los dos dataframes. Quitamos el inplace = True

df_new = df.dropna()
df_new.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %%
df_new.isnull().sum()
# Out:
# case_number    0
# unnamed:_0     0
# year           0
# type           0
# country        0
# area           0
# location       0
# activity       0
# name           0
# sex_           0
# age            0
# time           0
# species_       0
# href           0
# dtype: int64

# %% [markdown]
# ¿Cuántas filas se han eliminado con esta línea de código?

# %%
filas_antes, _ = df.shape

# %%
filas_despues, _ = df_new.shape

# %%
filas_eliminadas = filas_antes - filas_despues
filas_eliminadas
# Out:
# 4612

# %% [markdown]
# 2. ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
usa = df_new[df_new['country'] == 'USA']

# %%
# Numero de ataques en USA:

usa.shape[0]
# Out:
# 719

# %% [markdown]
# 3. ¿Y en España?

# %%
spain = df_new[df_new['country'] == 'SPAIN']

# %%
spain
# Out:
#        case_number  unnamed:_0    year        type country  \
# 98    2017.08.26.b          98  2017.0     Invalid   SPAIN
# 233     2016.07.29         234  2016.0  Unprovoked   SPAIN
# 377   2015.08.18.a         378  2015.0     Invalid   SPAIN
# 1007  2010.07.16.b        1011  2010.0    Provoked   SPAIN
# 2469    1993.09.03        2476  1993.0  Unprovoked   SPAIN
#
#                      area                        location  activity  \
# 98              Castellón                 Grao de Moncofa  Swimming
# 233     Alicante Province                Arenales del Sol  Swimming
# 377              Alicante        Poniente Beach, Benidorm  Swimming
# 1007  Grand Canary Island       Sardina del Norte, Gáldar  Swimming
# 2469         Costa Blanca  Playa de las Arenas, Valencia   Swimming
#
#                                      name sex_ age    time  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# ...

# %%
# Numero de ataques en SPAIN:

spain.shape[0]
# Out:
# 5

# %% [markdown]
# * 3.1 ¿En qué regiones se han producido los ataques?

# %%
spain['area']
# Out:
# 98                Castellón
# 233       Alicante Province
# 377                Alicante
# 1007    Grand Canary Island
# 2469           Costa Blanca
# Name: area, dtype: object

# %% [markdown]
# * 3.2 ¿Cuántos ataques se han producido en cada área?

# %%
# Lo mostramos filtrando

print('Castellón -->', df_new[df_new['area'] == 'Castellón'].shape[0])
print('Alicante Province -->', df_new[df_new['area'] == 'Alicante Province'].shape[0])
print('Alicante -->', df_new[df_new['area'] == 'Alicante'].shape[0])
print('Grand Canary Island -->', df_new[df_new['area'] == 'Grand Canary Island'].shape[0])
print('Costa Blanca -->', df_new[df_new['area'] == 'Costa Blanca'].shape[0])
# Out:
# Castellón --> 1
# Alicante Province --> 1
# Alicante --> 1
# Grand Canary Island --> 1
# Costa Blanca --> 1

# %%
# O con la funcion value_counts()

spain['area'].value_counts()
# Out:
# Castellón              1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# Name: area, dtype: int64

# %% [markdown]
# 4. Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos. 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.

# %%
# Con dos condiciones de filtrado

aus_usa = df_new[(df_new['country'] == 'AUSTRALIA') | (df_new['country'] == 'USA')]
aus_usa.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 8  2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
#
#                        location  activity         name sex_ age   time  \
# 0   Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
# 8  Cocoa Beach, Brevard  County   Walking    Cody High    M  15  17h00
#
#          species_                                               href
# 0     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  Bull shark, 6'  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
aus_usa.shape
# Out:
# (1043, 14)

# %%
# Con el metodo .isin()

aus_usa2 = df_new[df_new['country'].isin(['AUSTRALIA','USA'])]
aus_usa2.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 8  2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
#
#                        location  activity         name sex_ age   time  \
# 0   Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
# 8  Cocoa Beach, Brevard  County   Walking    Cody High    M  15  17h00
#
#          species_                                               href
# 0     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  Bull shark, 6'  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
aus_usa2.shape
# Out:
# (1043, 14)

# %% [markdown]
# * 4.1 ¿Cuántos ataques se han producido en cada país?

# %%
# En USA

usa = aus_usa[aus_usa['country'] == 'USA']
usa.shape[0]
# Out:
# 719

# %%
# En Australia

aus = aus_usa[aus_usa['country'] == 'AUSTRALIA']
aus.shape[0]
# Out:
# 324

# %% [markdown]
# * 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
# Comprobamos cómo puede estar escrito

aus['activity'].value_counts()
# Out:
# Surfing                                              87
# Swimming                                             40
# Spearfishing                                         22
# Fishing                                              13
# Snorkeling                                           10
#                                                      ..
# Abalone diving using Hookah (near calving whales)     1
# Playing / standing                                    1
# Dived naked into the water on a bet                   1
# Swimming breast stoke                                 1
# Bathing in knee-deep water                            1
# Name: activity, Length: 108, dtype: int64

# %%
# Filtramos para obtener el resultado preciso, no hay

aus[aus['activity'] == 'Paddling'].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# * 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
aus[aus['year'] <= 2000].shape[0]
# Out:
# 157

# %% [markdown]
# * 4.4 ¿Y después del 2000?

# %%
aus[aus['year'] >= 2000].shape[0]
# Out:
# 173

# %% [markdown]
# 5. Extraed unicamente los ataques a mujeres.

# %%
df_new[df_new['sex_'] == 'F'].head()
# Out:
#    case_number  unnamed:_0    year        type    country             area  \
# 0   2018.06.25           0  2018.0     Boating        USA       California
# 40  2018.02.23          40  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 53  2017.12.31          53  2017.0  Unprovoked        USA           Hawaii
# 71  2017.10.22          71  2017.0  Unprovoked  AUSTRALIA  South Australia
# 75  2017.10.05          75  2017.0  Unprovoked        USA           Hawaii
#
#                               location            activity              name  \
# 0          Oceanside, San Diego County            Paddling       Julie Wolfe
# 40  Little Congwong Beach, La Perouse             Swimming    Anna Shurapey
# 53                Hultin's Beach, Oahu             Surfing  Marjorie Mariano
# 71                         Normanville  Kayaking / Fishing    Sarah Williams
# 75          Kamaole Beach Park, Maui           Snorkeling            female
#
# ...

# %% [markdown]
# 6. ¿Cuántas mujeres fueron atacadas en España?

# %%
df_new[(df_new['sex_'] == 'F') & (df_new['country'] == 'SPAIN')].shape[0]
# Out:
# 1

# %% [markdown]
# 7. Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
years = df_new[df_new['year'].isin([200,1007,2006])]
years.head(1)
# Out:
#      case_number  unnamed:_0    year        type    country      area  \
# 1407  2006.12.18        1412  2006.0  Unprovoked  AUSTRALIA  Victoria
#
#                     location activity          name sex_ age   time  \
# 1407  Winki Pop, Bells Beach  Surfing  Peter Galvin    M  25  20h00
#
#               species_                                               href
# 1407  2.5 to 3 m shark  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 8. Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
df_new['species_'].unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
white_shark = df_new[df_new['species_'].str.contains('white', regex= True, case = False)]
white_shark['species_'].unique()
# Out:
# array(['White shark', 'White shark, 2.5 m',
#        'Juvenile white shark,  2.7 to 3.2 m', 'White shark, 4.6 m',
#        'White shark, 4.5 m', 'White shark, 3 to 3.5m ',
#        'White shark, 3 m', "White shark, 5' to 7'",
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        'White shark, 4 m', 'White shark, 3.5 m',
#        "White shark, 10' to 12'", "White shark, 11' to 12'",
#        "White shark, 10' to 12' ", "White shark, 13'",
#        'White shark, 3.9 to 4.2 m', "White shark, 7'",
#        'White shark, 2m to 3 m', 'White shark, 6 m',
#        'White shark or oceanic whitetip shark', 'White shark, 4 to 5 m',
#        '2 white shark: 13\' & 9"8"', "White shark, 12' to 14'",
#        " white shark, 15' ", '3 m to 4 m white shark', 'White shark, 3m ',
#        'Thought to involve a white shark', "White shark, 10 '",
#        "Whitetip reef shark, 4' to 6'", 'White shark, 4m',
#        "White shark, 15' to 16' ", 'White shark or bronze whaler',
# ...

# %% [markdown]
# 9. Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
white_tiger_shark = df_new[(df_new['species_'].str.contains('white', regex= True, case = False)) | 
                           (df_new['species_'].str.contains('tiger', regex= True, case = False))]

white_tiger_shark['species_'].unique()
# Out:
# array(['White shark', 'Tiger shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Juvenile white shark,  2.7 to 3.2 m',
#        'White shark, 4.6 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', 'White shark, 3 to 3.5m ',
#        'White shark, 3 m', "White shark, 5' to 7'",
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        'White shark, 4 m', 'White shark, 3.5 m', "Tiger shark, 10'",
#        "Tiger shark, 10' ", "White shark, 10' to 12'",
#        'Tiger shark, 2.5 m', "Tiger shark, 14'", "Tiger shark, 7'",
#        "Tiger shark, 13' ", "Tiger shark, 13'", "White shark, 11' to 12'",
#        "White shark, 10' to 12' ", "White shark, 13'",
#        'White shark, 3.9 to 4.2 m', "White shark, 7'",
#        'White shark, 2m to 3 m', 'Sandtiger shark', 'White shark, 6 m',
#        'Tiger shark, 8 to 12 feet', 'Tiger shark, 3.5 m',
#        'White shark or oceanic whitetip shark', 'White shark, 4 to 5 m',
# ...

# %% [markdown]
# 10. Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
# La forma de nuestro df antes de añadirle la columna:

df_new.shape
# Out:
# (1502, 14)

# %%
df_new['siglo'] = np.where((df_new['year']<2000), 'siglo-XX', 'siglo-XXI')
# Out:
# /tmp/ipykernel_2777/4270764431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['siglo'] = np.where((df_new['year']<2000), 'siglo-XX', 'siglo-XXI')

# %%
# Comprobamos que se ha añadido la columna

df_new.shape
# Out:
# (1502, 15)

# %%
df_new.head(1)
# Out:
#   case_number  unnamed:_0    year     type country        area  \
# 0  2018.06.25           0  2018.0  Boating     USA  California
#
#                       location  activity         name sex_ age   time  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
#
#       species_                                               href      siglo
# 0  White shark  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI

# %% [markdown]
# 11. Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
df_new.to_csv('attacks_modificado_2.csv')
