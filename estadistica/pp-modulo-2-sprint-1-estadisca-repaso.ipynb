# %% [markdown]
# Al igual que en los ejercicios de pair programming de estadística, deberéis elegir un set de datos, puede ser de cualquier tipo.
#
# El objetivo de este pair programming es:
#
# * Hacer una exploración inicial del dataframe.
# * ¿Cuántas filas tiene?
# * ¿Cuántas nulos tiene?
# * ¿Y duplicados?
# * ¿Qué tipo de datos tenemos en el dataframe?
# * etc.

# %%
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
df = pd.read_csv('ds_salaries.csv', index_col =0)

# %%
# Comprobamos su forma

df.shape
# Out:
# (607, 11)

# %%
# Chequeamos los nulos y no tiene, está muy limpio

df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Exploramos el nombre de sus columnas y el tipo de dato

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %%
# Calculamos los estadísticos generales para categóricas y numericas, ya que tenemos gran cantidad de variables categóricas

df.describe(include = 'all').T
# Out:
#                     count unique             top freq           mean  \
# work_year           607.0    NaN             NaN  NaN    2021.405272
# experience_level      607      4              SE  280            NaN
# employment_type       607      4              FT  588            NaN
# job_title             607     50  Data Scientist  143            NaN
# salary              607.0    NaN             NaN  NaN  324000.062603
# salary_currency       607     17             USD  398            NaN
# salary_in_usd       607.0    NaN             NaN  NaN  112297.869852
# employee_residence    607     57              US  332            NaN
# remote_ratio        607.0    NaN             NaN  NaN       70.92257
# company_location      607     50              US  355            NaN
# company_size          607      3               M  326            NaN
#
#                                std     min      25%       50%       75%  \
# ...

# %%
# Exploramos las filas duplicadas

df.duplicated().sum()
# Out:
# 42

# %%
# Vemos que no hay duplicados de fila completos, solo de algunas columnas. Vamos a comprobar si hay indices duplicados

df[df.duplicated()]
# Out:
#      work_year experience_level employment_type                  job_title  \
# 217       2021               MI              FT             Data Scientist
# 256       2021               MI              FT              Data Engineer
# 331       2022               SE              FT               Data Analyst
# 332       2022               SE              FT               Data Analyst
# 333       2022               SE              FT               Data Analyst
# 353       2022               SE              FT             Data Scientist
# 362       2022               SE              FT               Data Analyst
# 363       2022               SE              FT               Data Analyst
# 370       2022               SE              FT             Data Scientist
# 374       2022               MI              FT              ETL Developer
# 377       2022               SE              FT              Data Engineer
# ...

# %%
# No hay indices duplicados, por lo que nuestro conjunto de datos está listo para analizar!

df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Plantead una serie de preguntas como las que fuimos contestando en la clase invertida.

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
# ¿Cuanto se gana segun la experiencia?

df['experience_level']
df['salary_in_usd']

df['rangos_salario'] = pd.cut(df['salary_in_usd'], bins = (2000, 50000, 100000, 200000, 400000, 600000), labels = ['muy bajo', 'bajo', 'medio', 'alto', 'muy alto'])
crosstab = pd.crosstab(df['experience_level'], df['rangos_salario'])
crosstab
# Out:
# rangos_salario    muy bajo  bajo  medio  alto  muy alto
# experience_level
# EN                      38    40      8     2         0
# EX                       0     4     12     8         2
# MI                      58    89     60     3         3
# SE                      11    62    171    34         2

# %%
## Leyenda: EN - Junior | Entry level ; MI - Middle level | Intermediate ; SE - Senior level | Expert ; EX - Expert level | Director

# %%
# ¿Cual es el salario maximo y minimo y la experiencia y puesto de cada uno?

max = df['salary_in_usd'].max()
min = df['salary_in_usd'].min()

# %%
print('El salario máximo es', max)
print('------------')
print('El nivel de esta persona es:\n', df[df['salary_in_usd'] == max]['experience_level'].values)
# Out:
# El salario máximo es 600000
# ------------
# El nivel de esta persona es:
#  ['EX']

# %%
print('El salario mínimo es', min)
print('------------')
print('El nivel de esta persona :\n', df[df['salary_in_usd'] == min]['experience_level'].values)
# Out:
# El salario mínimo es 2859
# ------------
# El nivel de esta persona :
#  ['MI']

# %%
# Nos sorprende que una personal con nivel intermedio sea la que cobre el salario mínimo, vamos a comprobar su procedencia y la de su empresa para ver si no es un dato erroneo

# %%
# ¿Qué puesto de trabajo cobra más en USD?

# %%
# Frecuencia de job title y en que paises estan los mas frecuentes
# El nivel de experiencia en el sector data por paises
# ¿Cuántos trabajan de forma remota desde otro pais?
# ¿Con cuanta experiencia trabajan mas en remoto?

# %% [markdown]
# * Contestad a las preguntas planteadas usando los principales estadísticos que hemos aprendido y gráficas que mejor se ajusten.
